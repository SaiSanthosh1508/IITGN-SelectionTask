# %%
# !gdown 10heNH9MskIpqHAn7OksNA9eQGl0u07n4
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=10heNH9MskIpqHAn7OksNA9eQGl0u07n4
# From (redirected): https://drive.google.com/uc?id=10heNH9MskIpqHAn7OksNA9eQGl0u07n4&confirm=t&uuid=0379751e-35b8-47e4-945b-4cd001232c7f
# To: /kaggle/working/dataset.zip
# 100%|█████████████████████████████████████████| 888M/888M [00:06<00:00, 131MB/s]

# %%
# !unzip -q /kaggle/working/dataset.zip

# %%
# !pip install -q -U ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 16.5 MB/s eta 0:00:00a 0:00:01

# %%
# !gdown 1XowFAF71t5NUFulmmHyU95i3RiD2l6ff
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1XowFAF71t5NUFulmmHyU95i3RiD2l6ff
# To: /kaggle/working/config (1).yaml
# 100%|███████████████████████████████████████████| 137/137 [00:00<00:00, 533kB/s]

# %%
import os
os.rename("/kaggle/working/config (1).yaml","config.yaml")

# %%
os.rename("/kaggle/working/content/dataset/images_data","images")
os.rename("/kaggle/working/content/dataset/labels_data","labels")

# %%
# !yolo detect train data=/kaggle/working/config.yaml model=yolo11l.pt imgsz=416 epochs=300 batch=32 device=0,1 cos_lr=True seed=42
# Out:
# Ultralytics 8.3.78 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
#                                                        CUDA:1 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r -q runs.zip /kaggle/working/runs
